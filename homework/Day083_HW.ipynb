# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization, Activation
def build_mlp(input_shape,output_units = 10,num_neurons = [512,256,128], pre_activate = False):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    for i, n_units in enumerate(num_neurons):
        if i ==0:
            x = keras.layers.Dense(units = n_units,
                                  name = 'hidden_layer'+str(i+1))(input_layer)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation('relu')(x)
            else:
                x = Activation('relu')(x)
                x = BatchNormalization()(x) 
        else:
            x = keras.layers.Dense(units=n_units, 
                                   name="hidden_layer"+str(i+1))(x)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation("relu")(x)
            else:
                x = Activation("relu")(x)
                x = BatchNormalization()(x)
        
    out = keras.layers.Dense(activation = 'softmax',units = output_units, name = 'output')(x)
    model = keras.models.Model(inputs =[input_layer], outputs = [out] )
    
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = [2, 16, 32]
PRE_ACTIVATE = [False, True]
MOMENTUM = 0.95

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for i, (pre_act, batch) in enumerate(itertools.product(PRE_ACTIVATE,BATCH_SIZE)):
    keras.backend.clear_session()
    print("Pre activate batch normalization is %s and batch size is %i in number %i simulation" %(pre_act,batch,i))
    model = build_mlp(input_shape=x_train.shape[1:], pre_activate=pre_act)
    model.summary()
    opt = keras.optimizers.Adam(lr = LEARNING_RATE)
    model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = opt)
    
    model.fit(x_train,y_train,
             epochs = EPOCHS,
             batch_size = batch,
             validation_data= (x_test,y_test),
             shuffle = True)
    
    name_tag = ("pre_act %s, bz=%i" %(pre_act,batch))
    results[name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Pre activate batch normalization is False and batch size is 2 in number 0 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 25000/25000 [==============================] - 169s 7ms/step - loss: 2.3441 - accuracy: 0.1412 - val_loss: 3.0213 - val_accuracy: 0.2103
# Epoch 2/10
# 25000/25000 [==============================] - 173s 7ms/step - loss: 2.2363 - accuracy: 0.1642 - val_loss: 5.4672 - val_accuracy: 0.1907
# Epoch 3/10
# 25000/25000 [==============================] - 167s 7ms/step - loss: 2.2147 - accuracy: 0.1818 - val_loss: 3.2519 - val_accuracy: 0.2213
# Epoch 4/10
# 25000/25000 [==============================] - 165s 7ms/step - loss: 2.2138 - accuracy: 0.1818 - val_loss: 67.4691 - val_accuracy: 0.2177
# Epoch 5/10
# 25000/25000 [==============================] - 168s 7ms/step - loss: 2.2140 - accuracy: 0.1795 - val_loss: 16.3725 - val_accuracy: 0.2129
# Epoch 6/10
# 25000/25000 [==============================] - 167s 7ms/step - loss: 2.2137 - accuracy: 0.1806 - val_loss: 16.8255 - val_accuracy: 0.2021
# Epoch 7/10
# 25000/25000 [==============================] - 164s 7ms/step - loss: 2.2081 - accuracy: 0.1804 - val_loss: 29.6887 - val_accuracy: 0.1993
# Epoch 8/10
# 25000/25000 [==============================] - 160s 6ms/step - loss: 2.2162 - accuracy: 0.1835 - val_loss: 63.6233 - val_accuracy: 0.1756
# Epoch 9/10
# 25000/25000 [==============================] - 159s 6ms/step - loss: 2.2123 - accuracy: 0.1809 - val_loss: 68.6183 - val_accuracy: 0.1866
# Epoch 10/10
# 25000/25000 [==============================] - 158s 6ms/step - loss: 2.2141 - accuracy: 0.1808 - val_loss: 66.0607 - val_accuracy: 0.1939
# Pre activate batch normalization is False and batch size is 16 in number 1 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 3125/3125 [==============================] - 23s 7ms/step - loss: 1.9501 - accuracy: 0.3097 - val_loss: 1.8459 - val_accuracy: 0.3437
# Epoch 2/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.7019 - accuracy: 0.3949 - val_loss: 1.6453 - val_accuracy: 0.4134
# Epoch 3/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.6120 - accuracy: 0.4256 - val_loss: 1.6023 - val_accuracy: 0.4254
# Epoch 4/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.5446 - accuracy: 0.4461 - val_loss: 1.5263 - val_accuracy: 0.4647
# Epoch 5/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.5065 - accuracy: 0.4674 - val_loss: 1.5093 - val_accuracy: 0.4574
# Epoch 6/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.4740 - accuracy: 0.4731 - val_loss: 1.5563 - val_accuracy: 0.4508
# Epoch 7/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.4562 - accuracy: 0.4800 - val_loss: 1.4807 - val_accuracy: 0.4829
# Epoch 8/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.4364 - accuracy: 0.4926 - val_loss: 1.5238 - val_accuracy: 0.4627
# Epoch 9/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.4246 - accuracy: 0.4931 - val_loss: 1.5403 - val_accuracy: 0.4597
# Epoch 10/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.4040 - accuracy: 0.5009 - val_loss: 1.4154 - val_accuracy: 0.4985
# Pre activate batch normalization is False and batch size is 32 in number 2 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.8791 - accuracy: 0.3385 - val_loss: 2.2659 - val_accuracy: 0.2704
# Epoch 2/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.6006 - accuracy: 0.4266 - val_loss: 1.7902 - val_accuracy: 0.3849
# Epoch 3/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.5152 - accuracy: 0.4574 - val_loss: 1.6521 - val_accuracy: 0.4126
# Epoch 4/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.4491 - accuracy: 0.4837 - val_loss: 1.5975 - val_accuracy: 0.4401
# Epoch 5/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.4033 - accuracy: 0.4984 - val_loss: 1.4787 - val_accuracy: 0.4745
# Epoch 6/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.3487 - accuracy: 0.5190 - val_loss: 1.5521 - val_accuracy: 0.4594
# Epoch 7/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.3349 - accuracy: 0.5261 - val_loss: 1.5087 - val_accuracy: 0.4729
# Epoch 8/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2909 - accuracy: 0.5398 - val_loss: 1.4430 - val_accuracy: 0.4902
# Epoch 9/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2703 - accuracy: 0.5462 - val_loss: 1.5139 - val_accuracy: 0.4662
# Epoch 10/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2462 - accuracy: 0.5574 - val_loss: 1.4648 - val_accuracy: 0.4825
# Pre activate batch normalization is True and batch size is 2 in number 3 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 25000/25000 [==============================] - 157s 6ms/step - loss: 2.2965 - accuracy: 0.1450 - val_loss: 2.2207 - val_accuracy: 0.2395
# Epoch 2/10
# 25000/25000 [==============================] - 164s 7ms/step - loss: 2.2278 - accuracy: 0.1719 - val_loss: 2.2429 - val_accuracy: 0.2502
# Epoch 3/10
# 25000/25000 [==============================] - 164s 7ms/step - loss: 2.2158 - accuracy: 0.1788 - val_loss: 2.3189 - val_accuracy: 0.2272
# Epoch 4/10
# 25000/25000 [==============================] - 171s 7ms/step - loss: 2.2129 - accuracy: 0.1812 - val_loss: 2.3971 - val_accuracy: 0.2520
# Epoch 5/10
# 25000/25000 [==============================] - 163s 7ms/step - loss: 2.2022 - accuracy: 0.1853 - val_loss: 2.3877 - val_accuracy: 0.2467
# Epoch 6/10
# 25000/25000 [==============================] - 164s 7ms/step - loss: 2.2095 - accuracy: 0.1812 - val_loss: 2.3098 - val_accuracy: 0.2529
# Epoch 7/10
# 25000/25000 [==============================] - 167s 7ms/step - loss: 2.2052 - accuracy: 0.1837 - val_loss: 2.3319 - val_accuracy: 0.2474
# Epoch 8/10
# 25000/25000 [==============================] - 170s 7ms/step - loss: 2.2038 - accuracy: 0.1817 - val_loss: 2.2788 - val_accuracy: 0.2501
# Epoch 9/10
# 25000/25000 [==============================] - 169s 7ms/step - loss: 2.2138 - accuracy: 0.1752 - val_loss: 2.3949 - val_accuracy: 0.2378
# Epoch 10/10
# 25000/25000 [==============================] - 170s 7ms/step - loss: 2.2153 - accuracy: 0.1774 - val_loss: 2.4705 - val_accuracy: 0.2337
# Pre activate batch normalization is True and batch size is 16 in number 4 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.8318 - accuracy: 0.3452 - val_loss: 1.6081 - val_accuracy: 0.4188
# Epoch 2/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.5490 - accuracy: 0.4488 - val_loss: 1.5599 - val_accuracy: 0.4438
# Epoch 3/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.4554 - accuracy: 0.4831 - val_loss: 1.4920 - val_accuracy: 0.4577
# Epoch 4/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.3765 - accuracy: 0.5078 - val_loss: 1.5604 - val_accuracy: 0.4465
# Epoch 5/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.3248 - accuracy: 0.5308 - val_loss: 1.3523 - val_accuracy: 0.5199
# Epoch 6/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 1.2709 - accuracy: 0.5492 - val_loss: 1.4988 - val_accuracy: 0.4814
# Epoch 7/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.2193 - accuracy: 0.5647 - val_loss: 1.5399 - val_accuracy: 0.4602
# Epoch 8/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.1826 - accuracy: 0.5822 - val_loss: 1.4412 - val_accuracy: 0.4959
# Epoch 9/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.1416 - accuracy: 0.5981 - val_loss: 1.3667 - val_accuracy: 0.5262
# Epoch 10/10
# 3125/3125 [==============================] - 22s 7ms/step - loss: 1.1079 - accuracy: 0.6067 - val_loss: 1.4277 - val_accuracy: 0.5125
# Pre activate batch normalization is True and batch size is 32 in number 5 simulation
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.7822 - accuracy: 0.3682 - val_loss: 1.7316 - val_accuracy: 0.3856
# Epoch 2/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.4612 - accuracy: 0.4753 - val_loss: 1.6205 - val_accuracy: 0.4241
# Epoch 3/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.3601 - accuracy: 0.5163 - val_loss: 1.5109 - val_accuracy: 0.4656
# Epoch 4/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2732 - accuracy: 0.5451 - val_loss: 1.4745 - val_accuracy: 0.4814
# Epoch 5/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2028 - accuracy: 0.5700 - val_loss: 1.5533 - val_accuracy: 0.4639
# Epoch 6/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.1330 - accuracy: 0.5978 - val_loss: 1.5397 - val_accuracy: 0.4794
# Epoch 7/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0846 - accuracy: 0.6138 - val_loss: 1.4217 - val_accuracy: 0.4996
# Epoch 8/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0137 - accuracy: 0.6426 - val_loss: 1.7077 - val_accuracy: 0.4495
# Epoch 9/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9661 - accuracy: 0.6542 - val_loss: 1.5348 - val_accuracy: 0.4861
# Epoch 10/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9174 - accuracy: 0.6737 - val_loss: 1.4959 - val_accuracy: 0.5002

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
