# %% [markdown]
# # 作業重點:
#
# (1)以, Adam, 為例, 調整 batch_size, epoch , 觀察accurancy, loss 的變化
#
# (2)以同一模型, 分別驗證 SGD, Adam, Rmsprop 的 accurancy

# %% [markdown]
# # 作業目標:
#
#     取得各種優化器的運算結果

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
from keras import optimizers

# %%
#Blas GEMM launch failed , 避免動態分配GPU / CPU, 出現問題
import tensorflow as tf
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
'''
   宣告並設定
   batch_size：對總的樣本數進行分組，每組包含的樣本數量
   epochs ：訓練次數
   
''' 

batch_size = 32
num_classes = 10
epochs = 20
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#    第一步：選擇模型, 順序模型是多個網絡層的線性堆疊
 
model = Sequential()

#   第二步：構建網絡層
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數

# %%
# 模型建立完成後，統計參數總量
print("Total Parameters：%d" % model.count_params())
# Out:
# Total Parameters：1250858

# %%
# 輸出模型摘要資訊
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
#第三步編譯
'''
 SGD(隨機梯度下降) - Arguments
lr: float >= 0. Learning rate.
momentum: float >= 0. Parameter that accelerates SGD in the relevant direction and dampens oscillations.
decay: float >= 0. Learning rate decay over each update.
nesterov: boolean. Whether to apply Nesterov momentum.
'''
sgd = optimizers.SGD(lr=0.01, decay=1e-5, momentum=0.9, nesterov=True)
'''
RMSprop- Arguments
lr: float >= 0. Learning rate.
rho: float >= 0.
epsilon: float >= 0. Fuzz factor. If None, defaults to K.epsilon().
decay: float >= 0. Learning rate decay over each update.
'''
rms = optimizers.RMSprop(lr=0.01, epsilon=None, decay=1e-5) 
'''
Example:
opt = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

'''
adam = optimizers. Adam(lr=0.01, epsilon=None, decay=1e-5) 

model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# 資料正規化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# 是否要做資料處理
if not data_augmentation:
    print('Not using data augmentation.')
    history=model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_test, y_test),
                          shuffle=True)
else:
    print('Using real-time data augmentation.')
    print('')
        
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)
    history=model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_test, y_test),
                          shuffle=True)
    

'''
   第四步：訓練
   .fit的一些參數
   batch_size：對總的樣本數進行分組，每組包含的樣本數量
   epochs ：訓練次數
   shuffle：是否把數據隨機打亂之後再進行訓練
   validation_split：拿出百分之多少用來做交叉驗證
   verbose：屏顯模式 - 0：不輸出, 1：輸出進度, 2：輸出每次的訓練結果
'''
# Out:
# Using real-time data augmentation.
#
# Epoch 1/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.5115 - accuracy: 0.8208 - val_loss: 0.6990 - val_accuracy: 0.7643
# Epoch 2/20
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.4923 - accuracy: 0.8280 - val_loss: 0.6371 - val_accuracy: 0.7905
# Epoch 3/20
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.4895 - accuracy: 0.8298 - val_loss: 0.6590 - val_accuracy: 0.7833
# Epoch 4/20
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.4796 - accuracy: 0.8330 - val_loss: 0.6512 - val_accuracy: 0.7852
# Epoch 5/20
# 1563/1563 [==============================] - 90s 58ms/step - loss: 0.4719 - accuracy: 0.8352 - val_loss: 0.6582 - val_accuracy: 0.7904
# Epoch 6/20
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.4669 - accuracy: 0.8373 - val_loss: 0.6578 - val_accuracy: 0.7881
# Epoch 7/20
# 1563/1563 [==============================] - 85s 54ms/step - loss: 0.4531 - accuracy: 0.8420 - val_loss: 0.6516 - val_accuracy: 0.7867
# Epoch 8/20
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4475 - accuracy: 0.8431 - val_loss: 0.6456 - val_accuracy: 0.7886
# Epoch 9/20
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4384 - accuracy: 0.8463 - val_loss: 0.6558 - val_accuracy: 0.7914
# Epoch 10/20
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4274 - accuracy: 0.8504 - val_loss: 0.6518 - val_accuracy: 0.7863
# Epoch 11/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.4302 - accuracy: 0.8500 - val_loss: 0.6562 - val_accuracy: 0.7854
# Epoch 12/20
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4219 - accuracy: 0.8534 - val_loss: 0.6327 - val_accuracy: 0.7913
# Epoch 13/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.4135 - accuracy: 0.8571 - val_loss: 0.6681 - val_accuracy: 0.7892
# Epoch 14/20
# 1563/1563 [==============================] - 77s 50ms/step - loss: 0.4007 - accuracy: 0.8607 - val_loss: 0.6710 - val_accuracy: 0.7907
# Epoch 15/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.3993 - accuracy: 0.8611 - val_loss: 0.6715 - val_accuracy: 0.7875
# Epoch 16/20
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4003 - accuracy: 0.8607 - val_loss: 0.6308 - val_accuracy: 0.7989
# Epoch 17/20
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.3946 - accuracy: 0.8636 - val_loss: 0.6423 - val_accuracy: 0.7956
# Epoch 18/20
# 1563/1563 [==============================] - 76s 48ms/step - loss: 0.3799 - accuracy: 0.8679 - val_loss: 0.6585 - val_accuracy: 0.7892
# Epoch 19/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.3819 - accuracy: 0.8684 - val_loss: 0.6643 - val_accuracy: 0.7887
# Epoch 20/20
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.3699 - accuracy: 0.8735 - val_loss: 0.6628 - val_accuracy: 0.7928
# '\n   第四步：訓練\n   .fit的一些參數\n   batch_size：對總的樣本數進行分組，每組包含的樣本數量\n   epochs ：訓練次數\n   shuffle：是否把數據隨機打亂之後再進行訓練\n   validation_split：拿出百分之多少用來做交叉驗證\n   verbose：屏顯模式 - 0：不輸出, 1：輸出進度, 2：輸出每次的訓練結果\n'

# %%
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss of SGD:', scores[0])
print('Test accuracy of SGD:', scores[1])
# Out:
# Saved trained model at C:\Users\Conner Yang\saved_models\keras_cifar10_trained_model.h5
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6628 - accuracy: 0.7928
# Test loss of SGD: 0.6628073453903198
# Test accuracy of SGD: 0.7928000092506409

# %%
#    第六步：輸出
import numpy 

print ( " test set " )
scores = model.evaluate(x_test,y_test,batch_size=200,verbose= 0)
print ( "" )
#print ( " The test loss is %f " % scores)
print ( " The test loss is %f ", scores)


result = model.predict(x_test,batch_size=200,verbose= 0)

result_max = numpy.argmax(result, axis = 1 )
test_max = numpy.argmax(y_test, axis = 1 )

result_bool = numpy.equal(result_max, test_max)
true_num = numpy.sum(result_bool)
print(true_num)
# Out:
#  test set
#
#  The test loss is %f  [0.6628071069717407, 0.7928000092506409]
# 7928

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# %%
model.compile(optimizer = rms, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
datagen.fit(x_train)
history=model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_test, y_test),
                          shuffle=True)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 93s 60ms/step - loss: 2.3038 - accuracy: 0.1004 - val_loss: 2.3041 - val_accuracy: 0.1000
# Epoch 2/20
# 1563/1563 [==============================] - 88s 56ms/step - loss: 2.3039 - accuracy: 0.0997 - val_loss: 2.3040 - val_accuracy: 0.1000
# Epoch 3/20
# 1563/1563 [==============================] - 91s 58ms/step - loss: 2.3039 - accuracy: 0.0983 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 4/20
# 1563/1563 [==============================] - 88s 56ms/step - loss: 2.3038 - accuracy: 0.0978 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 5/20
# 1563/1563 [==============================] - 87s 56ms/step - loss: 2.3040 - accuracy: 0.0986 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 6/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 2.3040 - accuracy: 0.0977 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 7/20
# 1563/1563 [==============================] - 88s 56ms/step - loss: 2.3038 - accuracy: 0.0993 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 8/20
# 1563/1563 [==============================] - 95s 61ms/step - loss: 2.3038 - accuracy: 0.0985 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 9/20
# 1563/1563 [==============================] - 97s 62ms/step - loss: 2.3037 - accuracy: 0.1001 - val_loss: 2.3038 - val_accuracy: 0.1000
# Epoch 10/20
# 1563/1563 [==============================] - 105s 67ms/step - loss: 2.3038 - accuracy: 0.0996 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 11/20
# 1563/1563 [==============================] - 101s 65ms/step - loss: 2.3038 - accuracy: 0.1008 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 12/20
# 1563/1563 [==============================] - 109s 70ms/step - loss: 2.3037 - accuracy: 0.0991 - val_loss: 2.3038 - val_accuracy: 0.1000
# Epoch 13/20
# 1563/1563 [==============================] - 93s 59ms/step - loss: 2.3037 - accuracy: 0.1008 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 14/20
# 1563/1563 [==============================] - 98s 63ms/step - loss: 2.3036 - accuracy: 0.0992 - val_loss: 2.3045 - val_accuracy: 0.1000
# Epoch 15/20
# 1563/1563 [==============================] - 89s 57ms/step - loss: 2.3036 - accuracy: 0.1009 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 16/20
# 1563/1563 [==============================] - 81s 52ms/step - loss: 2.3036 - accuracy: 0.0983 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 17/20
# 1563/1563 [==============================] - 79s 51ms/step - loss: 2.3035 - accuracy: 0.1012 - val_loss: 2.3040 - val_accuracy: 0.1000
# Epoch 18/20
# 1563/1563 [==============================] - 80s 51ms/step - loss: 2.3037 - accuracy: 0.0998 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 19/20
# 1563/1563 [==============================] - 79s 51ms/step - loss: 2.3036 - accuracy: 0.1010 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 20/20
# 1563/1563 [==============================] - 87s 56ms/step - loss: 2.3035 - accuracy: 0.1000 - val_loss: 2.3037 - val_accuracy: 0.1000

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss of RMS:', scores[0])
print('Test accuracy of RMS:', scores[1])
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3037 - accuracy: 0.1000
# Test loss of RMS: 2.3036515712738037
# Test accuracy of RMS: 0.10000000149011612

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# %%
print ( " test set " )
scores = model.evaluate(x_test,y_test,batch_size=200,verbose= 0)
print ( "" )
#print ( " The test loss is %f " % scores)
print ( " The test loss is %f ", scores)
# Out:
#  test set
#
#  The test loss is %f  [2.3036508560180664, 0.10000000149011612]

# %%
model = Sequential()

#   第二步：構建網絡層
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數

# %%
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    history=model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_test, y_test),
                          shuffle=True)
else:
    print('Using real-time data augmentation.')
    print('')
        
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)
    history=model.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          validation_data=(x_test, y_test),
                          shuffle=True)
# Out:
# Using real-time data augmentation.
#
# Epoch 1/20
# 1563/1563 [==============================] - 76s 48ms/step - loss: 2.3038 - accuracy: 0.1018 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 2/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3036 - accuracy: 0.0993 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 3/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3037 - accuracy: 0.0992 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 4/20
# 1563/1563 [==============================] - 79s 50ms/step - loss: 2.3039 - accuracy: 0.0953 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 5/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3037 - accuracy: 0.0973 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 6/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3036 - accuracy: 0.0991 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 7/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3036 - accuracy: 0.0964 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 8/20
# 1563/1563 [==============================] - 79s 50ms/step - loss: 2.3034 - accuracy: 0.0974 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 9/20
# 1563/1563 [==============================] - 73s 47ms/step - loss: 2.3040 - accuracy: 0.0986 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 10/20
# 1563/1563 [==============================] - 74s 47ms/step - loss: 2.3035 - accuracy: 0.0987 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 11/20
# 1563/1563 [==============================] - 73s 47ms/step - loss: 2.3040 - accuracy: 0.0989 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 12/20
# 1563/1563 [==============================] - 73s 47ms/step - loss: 2.3038 - accuracy: 0.0966 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 13/20
# 1563/1563 [==============================] - 74s 47ms/step - loss: 2.3034 - accuracy: 0.1008 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 14/20
# 1563/1563 [==============================] - 74s 47ms/step - loss: 2.3037 - accuracy: 0.0984 - val_loss: 2.3038 - val_accuracy: 0.1000
# Epoch 15/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.3036 - accuracy: 0.1004 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 16/20
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3035 - accuracy: 0.0999 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 17/20
# 1563/1563 [==============================] - 82s 53ms/step - loss: 2.3036 - accuracy: 0.0990 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 18/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.3035 - accuracy: 0.1009 - val_loss: 2.3037 - val_accuracy: 0.1000
# Epoch 19/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.3039 - accuracy: 0.0980 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 20/20
# 1563/1563 [==============================] - 74s 47ms/step - loss: 2.3036 - accuracy: 0.1003 - val_loss: 2.3032 - val_accuracy: 0.1000

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss of adam:', scores[0])
print('Test accuracy of adam:', scores[1])
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3032 - accuracy: 0.1000
# Test loss of adam: 2.303215742111206
# Test accuracy of adam: 0.10000000149011612

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valiidation'], loc='upper left')
plt.show()

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
datagen.fit(x_train)
history=model.fit(x_train, y_train,
                          batch_size=64,
                          epochs=10,
                          validation_data=(x_test, y_test),
                          shuffle=True)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 65s 83ms/step - loss: 2.3030 - accuracy: 0.0997 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/10
# 782/782 [==============================] - 66s 85ms/step - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/10
# 782/782 [==============================] - 71s 91ms/step - loss: 2.3027 - accuracy: 0.1018 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/10
# 782/782 [==============================] - 67s 86ms/step - loss: 2.3026 - accuracy: 0.0997 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/10
# 782/782 [==============================] - 67s 86ms/step - loss: 2.3027 - accuracy: 0.0967 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/10
# 782/782 [==============================] - 66s 85ms/step - loss: 2.3026 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/10
# 782/782 [==============================] - 67s 85ms/step - loss: 2.3026 - accuracy: 0.0999 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/10
# 782/782 [==============================] - 67s 86ms/step - loss: 2.3027 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/10
# 782/782 [==============================] - 67s 86ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/10
# 782/782 [==============================] - 67s 86ms/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3026 - val_accuracy: 0.1000

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss of adam:', scores[0])
print('Test accuracy of adam:', scores[1])
# Out:
# 313/313 [==============================] - 2s 8ms/step - loss: 2.3026 - accuracy: 0.1000
# Test loss of adam: 2.302608013153076
# Test accuracy of adam: 0.10000000149011612
